# %% [markdown]
# # US election speech dataset
# This is a dataset from Kaggle. You can see the detail of this dataset from [Kaggle: US Election 2020 - Presidential Debates](https://www.kaggle.com/headsortails/us-election-2020-presidential-debates)
#
# I will try to do the following tasks:
#    - [x] find the speed of speech
#    - [ ] find the most frequent word
#    - [ ] find the attitude toward the debating topic
#    - [ ] train a RNN to translate the debate to other language

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %%
# import related packages 
import pandas as pd
import numpy as np

# %%
# import the data
df = pd.read_csv('../Data/US election speech/us_election_2020_1st_presidential_debate.csv')

# %%
# perform a check on data shape and quality
df.info()
df.shape
df.head(10)
df.tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789 entries, 0 to 788
# Data columns (total 3 columns):
# speaker    789 non-null object
# minute     788 non-null object
# text       789 non-null object
# dtypes: object(3)
# memory usage: 18.6+ KB
# (789, 3)
#                      speaker minute  \
# 0              Chris Wallace  01:20
# 1              Chris Wallace  02:10
# 2   Vice President Joe Biden  02:49
# 3  President Donald J. Trump  02:51
# 4   Vice President Joe Biden  02:51
# 5              Chris Wallace  03:11
# 6  President Donald J. Trump  04:01
# 7  President Donald J. Trump  04:53
# 8              Chris Wallace  05:22
# 9   Vice President Joe Biden  05:29
#
#                                                 text
# 0  Good evening from the Health Education Campus ...
# 1  This debate is being conducted under health an...
# 2                                How you doing, man?
# 3                                 How are you doing?
# 4                                          I’m well.
# 5  Gentlemen, a lot of people been waiting for th...
# 6  Thank you very much, Chris. I will tell you ve...
# 7  And we won the election and therefore we have ...
# 8  President Trump, thank you. Same question to y...
# 9  Well, first of all, thank you for doing this a...
#                        speaker    minute  \
# 779   Vice President Joe Biden  01:09:30
# 780  President Donald J. Trump  01:10:07
# 781              Chris Wallace  01:10:10
# 782   Vice President Joe Biden  01:10:15
# 783  President Donald J. Trump  01:10:41
# 784              Chris Wallace  01:10:43
# 785  President Donald J. Trump  01:10:47
# 786              Chris Wallace  01:10:48
# 787  President Donald J. Trump  01:10:49
# 788              Chris Wallace  01:10:50
#
#                                                   text
# 779  Yes. And here’s the deal. We count the ballots...
# 780  It’s already been established. Take a look at ...
# 781  I asked you. You had an opportunity to respond...
# 782  He has no idea what he’s talking about. Here’s...
# 783                I want to see an honest ballot cut-
# 784  Gentlemen, just say that’s the end of it [cros...
# 785              I want to see an honest ballot count.
# 786                     We’re going to leave it there-
# 787                           And I think he does too-
# 788  … to be continued in more debates as we go on....

# %%
# check for missing values
df.isnull().sum()

df['minute'][df['minute'].isnull()]

df.iloc[177:182,:]

df.iloc[179,2]
# Out:
# speaker    0
# minute     1
# text       0
# dtype: int64
# 179    NaN
# Name: minute, dtype: object
#                        speaker minute  \
# 177   Vice President Joe Biden  24:03
# 178  President Donald J. Trump  24:25
# 179             Chris Wallace:    NaN
# 180  President Donald J. Trump  00:15
# 181   Vice President Joe Biden  00:22
#
#                                                   text
# 177  His own CDC Director says we could lose as man...
# 178         You don’t trust Johnson & Johnson, Pfizer?
# 179  Okay, gentlemen, gentlemen. Let me move on to ...
# 180  Well, I’ve spoken to the companies and we can ...
# 181                                               God.
# 'Okay, gentlemen, gentlemen. Let me move on to questions about the future because you both have touched on two of the questions I’m going to ask. Focusing on the future first, President Trump, you have repeatedly either contradicted or been at odds with some of your governments own top scientists. The week before last, the Head of the Centers for Disease Control, Dr. Redfield said it would be summer before the vaccine would become generally available to the public. You said that he was confused and mistaken. Those were your two words. But Dr. Slaoui, the head of your Operation Warp Speed, has said exactly the same thing. Are they both wrong?'

# %% [markdown]
# We are going to make a variable call 'duration' to represent the time duration of the related text.
# However, we can see a mising data in row 179 and the minute count start from zero again.
# We can simply make the duration of this text equal to 0 for this moment and estimate the time duration of this text from chris later

# %%
# replace the nan by 0
for i in range(len(df)):
    if df.iloc[i,1] is np.nan:
        df.iloc[i,1] = '00:00'

# %%
# change the data type
df['duration'] = 0
for i in range(len(df)):
    if i == 0 :
        df['duration'][i] = pd.to_datetime(df.iloc[i,1],format = '%M:%S')-pd.to_datetime('00:00',format = '%M:%S')
        df['duration'][i] = df['duration'][i].seconds
    elif len(df.iloc[i,1]) == 5 and len(df.iloc[i-1,1]) == 5 :
        df['duration'][i] = pd.to_datetime(df.iloc[i,1],format = '%M:%S')-pd.to_datetime(df.iloc[i-1,1],format = '%M:%S')
        df['duration'][i] = df['duration'][i].seconds
    elif len(df.iloc[i,1]) == 8 and len(df.iloc[i-1,1]) == 5 :
        df['duration'][i] = pd.to_datetime(df.iloc[i,1],format = '%H:%M:%S')-pd.to_datetime(df.iloc[i-1,1],format = '%M:%S')
        df['duration'][i] = df['duration'][i].seconds
    elif len(df.iloc[i,1]) == 8:
        df['duration'][i] = pd.to_datetime(df.iloc[i,1],format = '%H:%M:%S')-pd.to_datetime(df.iloc[i-1,1],format = '%H:%M:%S')
        df['duration'][i] = df['duration'][i].seconds
df
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                        speaker    minute  \
# 0                Chris Wallace     01:20
# 1                Chris Wallace     02:10
# 2     Vice President Joe Biden     02:49
# 3    President Donald J. Trump     02:51
# 4     Vice President Joe Biden     02:51
# 5                Chris Wallace     03:11
# 6    President Donald J. Trump     04:01
# 7    President Donald J. Trump     04:53
# 8                Chris Wallace     05:22
# 9     Vice President Joe Biden     05:29
# 10   President Donald J. Trump     05:34
# 11    Vice President Joe Biden     05:36
# 12    Vice President Joe Biden     06:12
# 13    Vice President Joe Biden     07:08
# 14   President Donald J. Trump     07:34
# 15    Vice President Joe Biden     08:01
# 16   President Donald J. Trump     08:02
# 17    Vice President Joe Biden     08:24
# 18   President Donald J. Trump     08:25
# 19               Chris Wallace     08:29
# 20    Vice President Joe Biden     08:31
# 21               Chris Wallace     08:32
# 22    Vice President Joe Biden     08:33
# 23   President Donald J. Trump     08:58
# 24    Vice President Joe Biden     09:00
# 25   President Donald J. Trump     09:02
# 26    Vice President Joe Biden     09:05
# 766                           You’re urging them what?       28
# 767  … I am 100% on board. But if I see tens of tho...        1
# 768                 What does that mean, not go along-        8
# 769                             … from a common sense-        0
# 770   Does that mean you’re going to tell your people-        1
# 771                       I’ll tell you what it means-        1
# 772                          … to take to the streets?        0
# 773  It means you have a fraudulent election. You’r...        1
# 774                  And what would you do about that?        4
# 775  They’re not equipped… These people aren’t equi...        1
# 776                              Vice President Biden-       16
# 777                             You think that’s good?        0
# 778  Vice President Biden, final question for you. ...        1
# 779  Yes. And here’s the deal. We count the ballots...       12
# 780  It’s already been established. Take a look at ...       37
# 781  I asked you. You had an opportunity to respond...        3
# 782  He has no idea what he’s talking about. Here’s...        5
# 783                I want to see an honest ballot cut-       26
# 784  Gentlemen, just say that’s the end of it [cros...        2
# 785              I want to see an honest ballot count.        4
# 786                     We’re going to leave it there-        1
# 787                           And I think he does too-        1
# 788  … to be continued in more debates as we go on....        1
#
# [789 rows x 4 columns]

# %%
#df['duration'] = 0
df.iloc[177:182,:]
# Out:
#                        speaker minute  \
# 177   Vice President Joe Biden  24:03
# 178  President Donald J. Trump  24:25
# 179             Chris Wallace:  00:00
# 180  President Donald J. Trump  00:15
# 181   Vice President Joe Biden  00:22
#
#                                                   text duration
# 177  His own CDC Director says we could lose as man...        6
# 178         You don’t trust Johnson & Johnson, Pfizer?       22
# 179  Okay, gentlemen, gentlemen. Let me move on to ...    84935
# 180  Well, I’ve spoken to the companies and we can ...       15
# 181                                               God.        7

# %%
# before we make a simple estimation on the speaking speed, we need to do some math on the length of the speech.
def count(text):
    return len(text.split())

df['count'] = 0
for i in range(len(df)):
    df.iloc[i,4]=count(df.iloc[i,2])
    
df
# Out:
#                        speaker    minute  \
# 0                Chris Wallace     01:20
# 1                Chris Wallace     02:10
# 2     Vice President Joe Biden     02:49
# 3    President Donald J. Trump     02:51
# 4     Vice President Joe Biden     02:51
# 5                Chris Wallace     03:11
# 6    President Donald J. Trump     04:01
# 7    President Donald J. Trump     04:53
# 8                Chris Wallace     05:22
# 9     Vice President Joe Biden     05:29
# 10   President Donald J. Trump     05:34
# 11    Vice President Joe Biden     05:36
# 12    Vice President Joe Biden     06:12
# 13    Vice President Joe Biden     07:08
# 14   President Donald J. Trump     07:34
# 15    Vice President Joe Biden     08:01
# 16   President Donald J. Trump     08:02
# 17    Vice President Joe Biden     08:24
# 18   President Donald J. Trump     08:25
# 19               Chris Wallace     08:29
# 20    Vice President Joe Biden     08:31
# 21               Chris Wallace     08:32
# 22    Vice President Joe Biden     08:33
# 23   President Donald J. Trump     08:58
# 24    Vice President Joe Biden     09:00
# 25   President Donald J. Trump     09:02
# 26    Vice President Joe Biden     09:05
# 27   President Donald J. Trump     09:08
# 28    Vice President Joe Biden     09:09
# 29   President Donald J. Trump     09:11
# ..                         ...       ...
# 759              Chris Wallace  01:07:12
# 766                           You’re urging them what?       28      4
# 767  … I am 100% on board. But if I see tens of tho...        1     28
# 768                 What does that mean, not go along-        8      7
# 769                             … from a common sense-        0      5
# 770   Does that mean you’re going to tell your people-        1      9
# 771                       I’ll tell you what it means-        1      6
# 772                          … to take to the streets?        0      6
# 773  It means you have a fraudulent election. You’r...        1     13
# 774                  And what would you do about that?        4      7
# 775  They’re not equipped… These people aren’t equi...        1     48
# 776                              Vice President Biden-       16      3
# 777                             You think that’s good?        0      4
# 778  Vice President Biden, final question for you. ...        1     34
# 779  Yes. And here’s the deal. We count the ballots...       12    101
# 780  It’s already been established. Take a look at ...       37     11
# 781  I asked you. You had an opportunity to respond...        3     20
# 782  He has no idea what he’s talking about. Here’s...        5     90
# 783                I want to see an honest ballot cut-       26      8
# 784  Gentlemen, just say that’s the end of it [cros...        2     17
# 785              I want to see an honest ballot count.        4      8
# 786                     We’re going to leave it there-        1      6
# 787                           And I think he does too-        1      6
# 788  … to be continued in more debates as we go on....        1    122
#
# [789 rows x 5 columns]

# %%
# now we will estimate the normal speed of Chris for replacing the 'duration' of row 179
speaker_list = np.unique(df['speaker']).tolist()
speaker_list

df[df['speaker'] == 'Chris Wallace:']
df.iloc[179,0] = 'Chris Wallace'

speaker_list = np.unique(df['speaker']).tolist()
speaker_list
# Out:
# ['Chris Wallace',
#  'Chris Wallace:',
#  'President Donald J. Trump',
#  'Vice President Joe Biden']
#             speaker minute                                               text  \
# 179  Chris Wallace:  00:00  Okay, gentlemen, gentlemen. Let me move on to ...
#
#     duration  count
# 179    84935    112
# ['Chris Wallace', 'President Donald J. Trump', 'Vice President Joe Biden']

# %%
speaker_attr = {'speaker':[], 'speed':[]}

for speaker in speaker_list:
    word_count = 0
    duration = 0
    
    for i in range(len(df)):
        if df.iloc[i,0] == speaker and i != 179:
            word_count+= df.iloc[i,4]
            duration+= df.iloc[i,3]
    
    speed = word_count / duration
    speaker_attr['speaker'] .append(speaker)
    speaker_attr['speed'].append(speed)

speaker_attr
# Out:
# {'speaker': ['Chris Wallace',
#   'President Donald J. Trump',
#   'Vice President Joe Biden'],
#  'speed': [2.460625674217907, 3.3333333333333335, 3.9129662522202486]}

# %%
# now we can put back the estimated duration to row 179


####list(speaker_attr.items())[0][0]
df.iloc[179,3] = round(df.iloc[179,4]*list(speaker_attr.get('speed'))[0])
df.iloc[179,]
# Out:
# speaker                                         Chris Wallace
# minute                                                  00:00
# text        Okay, gentlemen, gentlemen. Let me move on to ...
# duration                                                  276
# count                                                     112
# Name: 179, dtype: object

# %%
#now we can show the speed of each speaker:
for i in range(len(list(speaker_attr.get('speaker')))):
    print('{} speaks {:.2f}words/s'.format(list(speaker_attr.get('speaker'))[i],list(speaker_attr.get('speed'))[i]))
# Out:
# Chris Wallace speaks 2.46words/s
# President Donald J. Trump speaks 3.33words/s
# Vice President Joe Biden speaks 3.91words/s
